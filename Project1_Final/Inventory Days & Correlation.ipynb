# %% [markdown]
# ## Python Analysis - Inventory Days & Correlation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("SampleSuperstore.csv", encoding='ISO-8859-1')


# Order Date to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

numeric_cols = ['Sales', 'Quantity', 'Discount', 'Profit']

# Correlation
corr_matrix = df[numeric_cols].corr()

# heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation between Sales, Quantity, Discount & Profit")
plt.show()

# %%
df['Inventory Turnover'] = df['Sales'] / df['Quantity']

# average turnover per sub-category
turnover_summary = df.groupby('Sub-Category')['Inventory Turnover'].mean().sort_values()
print(turnover_summary)
# Out:
# Sub-Category
# Fasteners        3.288756
# Labels           8.320423
# Art              8.818075
# Paper           15.578958
# Envelopes       18.874843
# Furnishings     25.607413
# Binders         36.672279
# Accessories     55.356630
# Appliances      60.618659
# Supplies        69.308105
# Storage         70.451459
# Phones         101.127993
# Bookcases      131.100152
# Chairs         138.802472
# Tables         165.088613
# Machines       423.352470
# Copiers        601.021029
# Name: Inventory Turnover, dtype: float64
